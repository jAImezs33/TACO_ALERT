# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 982.4/982.4 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# prompt: montar drive

from google.colab import drive
drive.mount('/content/drive')
# !pip install ultralytics
# Out:
# Mounted at /content/drive
# ...

# %%
from ultralytics import YOLO

# Cargar modelo best.pt
# Provide the full path to the 'best.pt' file
model_path = '/content/drive/MyDrive/GRUPO 4 SIC/TACO-RAMON/best.pt'
model = YOLO(model_path)

# Evaluación
results = model.val(
    data='/content/drive/MyDrive/GRUPO 4 SIC/TACO-RAMON/data.yaml',    # Ya adaptado para 60 clases y estructura YOLO
    imgsz=640,
    conf=0.25,
    iou=0.45,
    save=True,
    save_conf=True,
    plots=True
)

# Mostrar métricas por consola
print(results)
# Out:
# Ultralytics 8.3.113 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11l summary (fused): 190 layers, 25,325,572 parameters, 0 gradients, 86.8 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-891464d66343> in <cell line: 0>()
#       7
#       8 # Evaluación
# ----> 9 results = model.val(
#      10     data='/content/drive/MyDrive/GRUPO 4 SIC/TACO-RAMON/data.yaml',    # Ya adaptado para 60 clases y estructura YOLO
#      11     imgsz=640,
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in val(self, validator, **kwargs)
#     625
#     626         validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 627         validator(model=self.model)
#     628         self.metrics = validator.metrics
#     629         return validator.metrics
#
# ...
